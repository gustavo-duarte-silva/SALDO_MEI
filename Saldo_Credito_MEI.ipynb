# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavo-duarte-silva/SALDO_MEI/blob/main/Saldo_Credito_MEI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset obtido no PORTAL BRASILEIRO DE DADOS ABERTOS
#
# * https://dados.gov.br/dataset/27339-saldo-de-credito-por-estado-mei-mato-grosso/resource/1011caed-2791-42e8-8d92-45965dee1a44?inner_span=True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/CIENTISTA DE DADOS/PROJETOS/SALDO CREDITO MEI/bcdata.csv', sep=';')

# %%
#Tratamento dos Dados
def pre_processamento(df):
  dff = df.copy()
  dff['data'] = pd.to_datetime(dff.data, dayfirst=True, format='%d/%m/%Y')
  dff['valor'] = dff.valor.str.replace(',', '.').astype('float')
  return dff

# %%
dff = pre_processamento(df)

# %%
dff.dtypes
# Out:
# data     datetime64[ns]
# valor           float64
# dtype: object

# %%
plt.figure(figsize=[15,8])
sns.set_theme(style="darkgrid")
plt.title("Saldo de Crédito do MEI 2016-2021")
sns.lineplot(data=dff, x='data', y='valor')
plt.show()
